# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#mengimport dataset
hd = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Amikom Sehat/heart_disease_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-ffa95f443d02> in <module>()
#       1 #mengimport dataset
# ----> 2 hd = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/heart_disease_data.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#membaca data set hd
hd

# %%
hd = hd[['sex', 'age', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']]

# %%
hd

# %%
#membaca 5 data teratas dari dataset
hd.head()

# %%
#membaca 5 data terakhir dari dataset
hd.tail()

# %%
#mengetahui berapa baris dan kolom
hd.shape

# %%
#mengetahui info data
hd.info()

# %%
#melihat apakah ada data yang kosong
hd.isnull().sum()

# %%
#melihat statistik data
hd.describe()

# %%
# memeriksa distribusi data Variabel Target ( 1 : positif , 0 : negatif )
hd['target'].value_counts()

# %%
# memeriksa distribusi Variabel Target
hd['sex'].value_counts()

# %%
pd.crosstab(hd['sex'], hd['target'])

# %%
hd

# %%
#X : data selain kolom target
X = hd.drop(['cp','oldpeak', 'slope','ca','target'], axis=1)

#Y : data kolom target
Y = hd['target']

# %%
#melihat data x
X

# %%
#melihat data Y
Y

# %%
#memisahkan data mejadi data training dan data test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape, Y.shape, Y_train.shape, Y_test.shape)

# %%
len(X_test)

# %%
len(X_train)

# %%
#Menggunakan model logika regressi
model = LogisticRegression()

# %%
#Training model logika regressi dengan data training
model.fit(X_train, Y_train)

# %%
# Acurracy pada data training

X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy pada data training : ', training_data_accuracy)

# %%
input_data = (0,	57,	130,	236,	0,	0,	174,	0,	2)

#mennganti input data menjadi numpy array
input_data_array = np.array(input_data)

#
input_data_reshape = input_data_array.reshape(1,-1)

prediksi = model.predict(input_data_reshape)
print(prediksi)

if (prediksi[0]==0):
  print('Anda tidak mempunyai penyakit jatung')
else:
  print('Anda mempunyai penyakit jantung')

# %%
import pickle
filename = 'model_PJ.pkl'
pickle.dump(model, open(filename, 'wb'))
